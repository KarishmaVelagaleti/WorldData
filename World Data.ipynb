# %%
import pandas as pd 
import numpy as np 
import os

# %%
os.listdir()
# Out:
# ['world-happiness-report-2021.csv.xls',
#  'HNP_StatsData.csv',
#  'HNP_StatsCountry-Series.csv',
#  'Untitled.ipynb',
#  'cost-of-living-2018.csv',
#  'world-happiness-report.csv.xls',
#  'healthy_lifestyle_city_2021.csv.xls',
#  '.ipynb_checkpoints',
#  'HNPQCountry.csv',
#  'HNP_StatsCountry.csv']

# %%
happiness=pd.read_csv("world-happiness-report-2021.csv.xls")
happiness.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
hnp = pd.read_csv("HNP_StatsData.csv")
hnp.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name  Indicator Code  \
# 0  Adolescent fertility rate (births per 1,000 wo...     SP.ADO.TFRT
# 1  Adults (ages 15+) and children (0-14 years) li...     SH.HIV.TOTL
# 2  Adults (ages 15+) and children (ages 0-14) new...  SH.HIV.INCD.TL
# 3                  Adults (ages 15+) living with HIV     SH.DYN.AIDS
# 4          Adults (ages 15+) newly infected with HIV     SH.HIV.INCD
#
#          1960        1961        1962       1963        1964        1965  ...  \
# 0  134.223612  134.838634  135.570905  135.44464  135.274904  134.947174  ...
# 1         NaN         NaN         NaN        NaN         NaN         NaN  ...
# 2         NaN         NaN         NaN        NaN         NaN         NaN  ...
# ...

# %%
hnp2 = pd.read_csv('HNP_StatsCountry-Series.csv')
hnp2.head()
# Out:
#   CountryCode      SeriesCode  \
# 0         ABW     SM.POP.NETM
# 1         ABW  SP.DYN.AMRT.FE
# 2         ABW  SP.DYN.AMRT.MA
# 3         ABW  SP.DYN.CBRT.IN
# 4         ABW  SP.DYN.CDRT.IN
#
#                                          DESCRIPTION  Unnamed: 3
# 0  Data sources : United Nations World Population...         NaN
# 1  Data source : United Nations World Population ...         NaN
# 2  Data source : United Nations World Population ...         NaN
# 3  Data sources : United Nations World Population...         NaN
# 4  Data sources : United Nations World Population...         NaN

# %%
hnp3=pd.read_csv('HNPQCountry.csv')
hnp3.head()
# Out:
#   Country Code   Short Name   Table Name                     Long Name  \
# 0          ABW        Aruba        Aruba                         Aruba
# 1          AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 2          AGO       Angola       Angola   People's Republic of Angola
# 3          ALB      Albania      Albania           Republic of Albania
# 4          AND      Andorra      Andorra       Principality of Andorra
#
#   2-alpha code   Currency Unit  \
# 0           AW   Aruban florin
# 1           AF  Afghan afghani
# 2           AO  Angolan kwanza
# 3           AL    Albanian lek
# 4           AD            Euro
#
#                                        Special Notes  \
# 0  SNA data for 2000-2011 are updated from offici...
# 1  Fiscal year end: March 20; reporting period fo...
# 2                                                NaN
# 3                                                NaN
# 4  WB-3 code changed from ADO to AND to align wit...
#
# ...

# %%
hnp4= pd.read_csv('HNP_StatsCountry.csv')
hnp4.head()
# Out:
#   Country Code   Short Name   Table Name                     Long Name  \
# 0          ABW        Aruba        Aruba                         Aruba
# 1          AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 2          AGO       Angola       Angola   People's Republic of Angola
# 3          ALB      Albania      Albania           Republic of Albania
# 4          AND      Andorra      Andorra       Principality of Andorra
#
#   2-alpha code   Currency Unit  \
# 0           AW   Aruban florin
# 1           AF  Afghan afghani
# 2           AO  Angolan kwanza
# 3           AL    Albanian lek
# 4           AD            Euro
#
#                                        Special Notes  \
# 0  Central Bureau of Statistics and Central Bank ...
# 1  Central Statistics Organization; World Bank st...
# 2  IMF ; Source of population estimates: UN Popul...
# 3  Albanian Institute of Statistics ; Source of p...
# 4  Government of Andorra, Department of Statistic...
#
# ...

# %%
col = pd.read_csv('cost-of-living-2018.csv')
col.head()
# Out:
#    Rank                 City  Cost of Living Index  Rent Index  \
# 0   NaN    Hamilton, Bermuda                145.43      110.87
# 1   NaN  Zurich, Switzerland                141.25       66.14
# 2   NaN  Geneva, Switzerland                134.83       71.70
# 3   NaN   Basel, Switzerland                130.68       49.68
# 4   NaN    Bern, Switzerland                128.03       43.57
#
#    Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                          128.76           143.47                  158.75
# 1                          105.03           149.86                  135.76
# 2                          104.38           138.98                  129.74
# 3                           91.61           127.54                  127.22
# 4                           87.30           132.70                  119.48
#
#    Local Purchasing Power Index
# 0                        112.26
# 1                        142.70
# 2                        130.96
# ...

# %%
happiness2= pd.read_csv('world-happiness-report.csv.xls')
happiness2.head()
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724               7.370           0.451
# 1  Afghanistan  2009        4.402               7.540           0.552
# 2  Afghanistan  2010        4.758               7.647           0.539
# 3  Afghanistan  2011        3.832               7.620           0.521
# 4  Afghanistan  2012        3.783               7.705           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                             50.80                         0.718       0.168
# 1                             51.20                         0.679       0.190
# 2                             51.60                         0.600       0.121
# 3                             51.92                         0.496       0.162
# 4                             52.24                         0.531       0.236
#
#    Perceptions of corruption  Positive affect  Negative affect
# ...

# %%
happiness2["year"].max()
# Out:
# 2020

# %%
lifestyle = pd.read_csv('healthy_lifestyle_city_2021.csv.xls')
lifestyle.head()
# Out:
#          City  Rank Sunshine hours(City) Cost of a bottle of water(City)  \
# 0   Amsterdam     1                 1858                           £1.92
# 1      Sydney     2                 2636                           £1.48
# 2      Vienna     3                 1884                           £1.94
# 3   Stockholm     4                 1821                           £1.72
# 4  Copenhagen     5                 1630                           £2.19
#
#   Obesity levels(Country)  Life expectancy(years) (Country)  \
# 0                  20.40%                              81.2
# 1                  29.00%                              82.1
# 2                  20.10%                              81.0
# 3                  20.60%                              81.8
# 4                  19.70%                              79.8
#
#   Pollution(Index score) (City) Annual avg. hours worked  \
# 0                         30.93                     1434
# ...
